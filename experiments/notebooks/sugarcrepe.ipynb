# %%
from datasets import load_dataset
import json
from tqdm.auto import tqdm

# %%
sc_rep_att = load_dataset('HuggingFaceM4/SugarCrepe_replace_att')

# %%
sc_rep_att
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['image', 'tested_labels', 'true_label'],
#         num_rows: 788
#     })
# })

# %%
sc_rep_att['test'][0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=351x500>,
#  'tested_labels': ['A tan toilet and sink combination in a small room.',
#   'A white toilet and sink combination in a small room.'],
#  'true_label': 1557}

# %%
sc_rep_att['test'][1]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x640>,
#  'tested_labels': ['Frisbee in the air, a dog squatting looking up at it, and a man standing behind the dog watching it, on the grass with a tree.',
#   'Frisbee in the air, a dog squatting looking up at it, and a man sitting behind the dog watching it, on the grass with a tree.'],
#  'true_label': 997}

# %%
#coco = load_dataset('HuggingFaceM4/COCO', trust_remote_code=True)

# %%
sc_rep_att['test'][1]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x640>

# %%
with open ('/home/drdo/vlm-compositionality/data/raw/sugarcrepe/add_obj.json') as f:
    sc_add_obj = json.load(f)

# %%
sc_add_obj['0']
# Out:
# {'filename': '000000219578.jpg',
#  'caption': 'A cat and dog napping together on the couch.',
#  'negative_caption': 'A cat and a dog napping together under a blanket on the couch.'}
